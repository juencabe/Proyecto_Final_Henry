# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Migraciones

# %%
cod_paises = pd.read_csv('Datasets/Metadata_Country_API_SM.POP.NETM_DS2_es_csv_v2_5368209.csv')
migracion_neta_por_anio = pd.read_csv('Datasets/API_SM.POP.NETM_DS2_es_csv_v2_5368209.csv',skiprows=4)

# %%
cod_paises = cod_paises.iloc[:,:-1]
cod_paises
# Out:
#         Country Name Country Code  \
# 0              Aruba          ABW
# 1                NaN          AFE
# 2         Afganistán          AFG
# 3                NaN          AFW
# 4             Angola          AGO
# ..               ...          ...
# 261           Kosovo          XKX
# 262  Yemen, Rep. del          YEM
# 263        Sudáfrica          ZAF
# 264           Zambia          ZMB
# 265         Zimbabwe          ZWE
#
#                                                 Region
# 0                                                  NaN
# 1                                                  NaN
# 2                                      Asia meridional
# 3                                                  NaN
# 4    África al sur del Sahara (excluido altos ingre...
# ..                                                 ...
# 261    Europa y Asia central (excluido altos ingresos)
# 262  Oriente Medio y Norte de África (excluido alto...
# ...

# %%
cod_paises.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  264 non-null    object
#  1   Country Code  266 non-null    object
#  2   Region        136 non-null    object
# dtypes: object(3)
# memory usage: 6.4+ KB

# %%
cod_paises.duplicated().unique()
# Out:
# array([False])

# %% [markdown]
# * columnas de relacion:
#     - Country Code
#     - Country Name
#
# * tipos de datos:
#     - catergoticos:
#         - nominal:
#             - Country Name
#             - Country Code
#             - Region
#             - Income_Group
#
# * Datos Faltantes:
#     - Hay valores faltantes en :
#         - Country Name(2)
#         - Region(130)
#
#     - Propuesta: llenar a mano los datos faltantes.
#
# * Sin datos duplicados

# %% [markdown]
# * redusco el dataset de migracionse a el rango de 2000 a 2021

# %%
migracion_neta_por_anio = pd.concat([migracion_neta_por_anio.iloc[:,:4],migracion_neta_por_anio.iloc[:,-23:-1]],axis=1)

# %%
migracion_neta_por_anio
# Out:
#         Country Name Country Code  Indicator Name Indicator Code       2000  \
# 0              Aruba          ABW  Migración neta    SM.POP.NETM     1235.0
# 1                NaN          AFE  Migración neta    SM.POP.NETM  -564510.0
# 2         Afganistán          AFG  Migración neta    SM.POP.NETM -1007135.0
# 3                NaN          AFW  Migración neta    SM.POP.NETM   -22651.0
# 4             Angola          AGO  Migración neta    SM.POP.NETM    53527.0
# ..               ...          ...             ...            ...        ...
# 261           Kosovo          XKX  Migración neta    SM.POP.NETM    -9176.0
# 262  Yemen, Rep. del          YEM  Migración neta    SM.POP.NETM   -87753.0
# 263        Sudáfrica          ZAF  Migración neta    SM.POP.NETM   -80388.0
# 264           Zambia          ZMB  Migración neta    SM.POP.NETM    -5152.0
# 265         Zimbabwe          ZWE  Migración neta    SM.POP.NETM  -137321.0
#
# ...

# %%
migracion_neta_por_anio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    264 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   2000            265 non-null    float64
#  5   2001            265 non-null    float64
#  6   2002            265 non-null    float64
#  7   2003            265 non-null    float64
#  8   2004            265 non-null    float64
#  9   2005            265 non-null    float64
#  10  2006            265 non-null    float64
#  11  2007            265 non-null    float64
#  12  2008            265 non-null    float64
#  13  2009            265 non-null    float64
#  14  2010            265 non-null    float64
#  15  2011            265 non-null    float64
#  16  2012            265 non-null    float64
# ...

# %%
migracion_neta_por_anio.duplicated().unique()
# Out:
# array([False])

# %%
migracion_neta_por_anio['Indicator Name'].unique()
migracion_neta_por_anio['Indicator Code'].unique()
# Out:
# array(['SM.POP.NETM'], dtype=object)

# %% [markdown]
# * columnas de relacion:
#     - Country Name
#     - Country Code
# * tipos de datos:
#     - catergoticos:
#         - nominal:
#             - Indicator Name
#             - Indicator Code
#
#     - cuantitativos:
#         - discretos:
#             - columnas de 2000 a 2021(1)
#
# * Datos Faltantes:
#     - Hay valores faltantes en :
#         - columnas de 2000 a 2021(1)
#
# * Observaciones:
#     - La fila de "No clasificado" con codigo de pais "INX" no posee datos para ningun anio.
#     - Indicator Name e Indicator code tienen un unico valor
#
# * Propuestas:
#     - para los valores faltantes de Country Name: agregarlos a mano o usando la tabla de cod_paises
#     - para la fija de 'No clasificado': eliminarla pues no hay datos ni forma de completar la

# %% [markdown]
# # Remesas

# %%
remesas_entrantes= pd.read_excel('remesas/inward_remittance_flows_as_of_dec._2_2022_0.xlsx',decimal='.',)
remesas_salientes= pd.read_excel('remesas/outward_remittance_flows_brief_37_as_of_nov28_2022_2_1.xlsx',skiprows=1)

# %% [markdown]
# ### Remesas Entrantes

# %% [markdown]
# * Saco las 10 ulitmas filas pues son observaciones, y limito el rango de anio a 2000 a 2022

# %%
remesas_entrantes = pd.concat([remesas_entrantes.iloc[:,0],remesas_entrantes.iloc[:,-24:-1]],axis=1)
remesas_entrantes = remesas_entrantes.iloc[:-10]

# %%
remesas_entrantes.head()
# Out:
#   Migrant remittance inflows (US$ million)   2000   2001    2002        2003  \
# 0                              Afghanistan    0.0    0.0    0.00    0.000000
# 1                                  Albania  597.8  699.3  733.57  888.748582
# 2                                  Algeria    0.0    0.0    0.00    0.000000
# 3                           American Samoa    NaN    NaN     NaN         NaN
# 4                                  Andorra    0.0    0.0    0.00    0.000000
#
#           2004         2005         2006       2007        2008  ...  \
# 0     0.000000     0.000000            0          0        89.5  ...
# 1  1160.672105  1289.704316  1359.467325    1468.02      1865.6  ...
# 2     0.000000   170.000000        189.0  99.004563  103.631887  ...
# 3          NaN          NaN          NaN        NaN         NaN  ...
# 4     0.000000          NaN          NaN        NaN         NaN  ...
#
#           2013         2014         2015         2016         2017  \
# ...

# %%
remesas_entrantes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 24 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Migrant remittance inflows (US$ million)  216 non-null    object
#  1   2000                                      202 non-null    float64
#  2   2001                                      202 non-null    float64
#  3   2002                                      202 non-null    float64
#  4   2003                                      202 non-null    float64
#  5   2004                                      202 non-null    float64
#  6   2005                                      195 non-null    float64
#  7   2006                                      196 non-null    object
#  8   2007                                      196 non-null    object
#  9   2008                                      196 non-null    object
# ...

# %%
remesas_entrantes.duplicated().unique()
# Out:
# array([False])

# %% [markdown]
# * columnas de relacion:
#
# * tipos de datos:
#     - catergoticos:
#         - nominal:
#             - Migrant remittance inflows (US$ million)
#
#     - cuantitativos:
#         - continuos:
#             - columnas de la segunda a la ultiama
#
# * Datos Faltantes:
#     - Hay valores faltantes en :
#         - todas exepto la primera
# * Observaciones:
#     - solo hay datos de 215 paices y un total del mundo
#     - hay datos hasta el 2022
#
# * Propuesta:
#     - ante datos nulos llenar con ceros.
#     - cambiar el monbre dela pirmera columna a Country o Pais

# %% [markdown]
# ### Remesas Saliente

# %% [markdown]
# * Saco las 10 ulitmas filas pues son observaciones, y limito el rango de anio a 2000 a 2022

# %% [markdown]
# * limito el rango de 2000 a 2021, y saco las 10 ultimas columnas del excel que son informaicion.

# %%
remesas_salientes = pd.concat([remesas_salientes.iloc[:,0],remesas_salientes.iloc[:-10,11:-49]],axis=1)
remesas_salientes = remesas_salientes.iloc[:-11]

# %%
remesas_salientes
# Out:
#     Outward remittance flows (US$ million)  2000       2001       2002  \
# 0                              Afghanistan   NaN        NaN        NaN
# 1                                  Albania   0.0   0.000000   0.000000
# 2                                  Algeria   NaN        NaN        NaN
# 3                           American Samoa   NaN        NaN        NaN
# 4                                  Andorra   NaN        NaN        NaN
# ..                                     ...   ...        ...        ...
# 209                  Virgin Islands (U.S.)   NaN        NaN        NaN
# 210                     West Bank and Gaza   5.6   4.900869   5.095333
# 211                            Yemen, Rep.   NaN        NaN        NaN
# 212                                 Zambia  24.1  28.400000  37.500000
# 213                               Zimbabwe   0.0   0.000000   0.000000
#
#           2003       2004        2005        2006        2007        2008  \
# ...

# %%
remesas_salientes['Outward remittance flows (US$ million)'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
# ...

# %%
remesas_salientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 214 entries, 0 to 213
# Data columns (total 23 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Outward remittance flows (US$ million)  214 non-null    object
#  1   2000                                    153 non-null    float64
#  2   2001                                    154 non-null    float64
#  3   2002                                    162 non-null    float64
#  4   2003                                    163 non-null    float64
#  5   2004                                    165 non-null    float64
#  6   2005                                    174 non-null    float64
#  7   2006                                    177 non-null    float64
#  8   2007                                    180 non-null    float64
#  9   2008                                    181 non-null    float64
# ...

# %%
remesas_salientes.duplicated().unique()
# Out:
# array([False])

# %% [markdown]
# * columnas de relacion:
#
# * tipos de datos:
#     - catergoticos:
#         - nominal:
#             - Outward remittance flows (US$ million)
#
#     - cuantitativos:
#         - continuos:
#             - columnas de la segunda a la ultiama
#
# * Datos Faltantes:
#     - Hay valores faltantes en :
#         - la unica completa es la primer columna
#
# * Duplicados: niguno
# * Observaciones:
#     - solo hay datos de 214 paices
#     - solo hay datos hasta el 2021
#
# * Propuesta:
#     - ante datos continuos nulos llenar con ceros.
#     - cambiar el monbre de la pirmera columna a Country o Pais
